# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from csv import writer

# %%
URL =  "https://www.pararius.com/apartments/amsterdam"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')
lists = soup.find_all('section', class_ = 'listing-search-item' )

# %%
with open('housing.csv', 'w', encoding ='utf8', newline='') as f:
    thewriter = writer(f)
    header = ['Title', 'Location','Price','Area','Rooms']
    thewriter.writerow(header)
    
    for list in lists:
        title = list.find('a', class_ = 'listing-search-item__link--title').text.replace('\n', '')
        location = list.find('div', class_ = 'listing-search-item__sub-title').text.replace('\n', '') 
        price = list.find('div', class_ = 'listing-search-item__price').text.replace('\n', '')
        area = list.find('li', class_ = 'illustrated-features__item illustrated-features__item--surface-area').text.replace('\n', '')
        rooms = list.find('li', class_ = 'illustrated-features__item illustrated-features__item--number-of-rooms').text.replace('\n', '')
        info = [title, location, price, area, rooms]
        thewriter.writerow(info)

# %%
df = []

# %%
   for list in lists:
        title = list.find('a', class_ = 'listing-search-item__link--title').text.replace('\n', '')
        location = list.find('div', class_ = 'listing-search-item__sub-title').text.replace('\n', '') 
        price = list.find('div', class_ = 'listing-search-item__price').text.replace('\n', '')
        area = list.find('li', class_ = 'illustrated-features__item illustrated-features__item--surface-area').text.replace('\n', '')
        rooms = list.find('li', class_ = 'illustrated-features__item illustrated-features__item--number-of-rooms').text.replace('\n', '')
        info = [title, location, price, area, rooms]
        df.append(info)

# %%
df = pd.DataFrame(df)
df.columns = ['Title', 'Location','Price','Area','Rooms']

# %%
df
# Out:
#                                                 Title  \
# 0                           Apartment Sprinklerstr...
# 1                           Apartment Veldhuizenst...
# 2                           Apartment Pieter Calan...
# 3                           Apartment Rustenburger...
# 4                           Apartment Groen van Pr...
# 5                           Apartment Korte Ouderk...
# 6                           Apartment Dusartstraat...
# 7                           Apartment Rheastraat 2...
# 8                           Apartment Tolstraat 42...
# 9                           Apartment Gillis van L...
# 10                          Apartment Willem Nakke...
# 11                          Apartment Banstraat 55...
# 12                          Apartment Prinsengrach...
# 13                          Apartment Oudezijds Ac...
# 14                          Studio Sarphatistraat ...
# 15                          Apartment NDSM-pier   ...
# 16                          Apartment NDSM-pier   ...
# 17                          Apartment NDSM-pier   ...
# 18                          House H. Stolleplantso...
# 19                          Apartment Nieuwe Heren...
# 20                          Apartment Keizersgrach...
# 21                          Apartment Herenstraat ...
# 22                          Apartment Herengracht ...
# 23                          Apartment Alexanderkad...
# 24                          Apartment Johannes Ver...
# 25                          Apartment Blasiusstraa...
# 26                          Apartment Nova Zemblas...
# 27                          Apartment Jennerstraat...
# 28                          Apartment Jacob van Le...
# 29                          Apartment Lauriergrach...
#
#                                              Location  \
# 0               1019 VR Amsterdam (Indische Buurt ...
# 1                    1106 DH Amsterdam (Gein)
# 2               1069 SC Amsterdam (Osdorp-Midden) ...
# 3               1073 GJ Amsterdam (Nieuwe Pijp)   ...
# 4               1051 EH Amsterdam (Staatsliedenbuu...
# 5               1096 AC Amsterdam (Omval/Overamste...
# 6               1072 HV Amsterdam (Nieuwe Pijp)   ...
# 7               1076 DS Amsterdam (Stadionbuurt)  ...
# 8               1073 SC Amsterdam (Zuid Pijp)
# 9               1052 VG Amsterdam (Frederik Hendri...
# 10              1061 SZ Amsterdam (Overtoomse Veld...
# 11              1071 JX Amsterdam (Museumkwartier)...
# 12              1016 HS Amsterdam (Grachtengordel-...
# 13              1012 DG Amsterdam (Burgwallen-Oude...
# 14              1018 AV Amsterdam (Weesperbuurt/Pl...
# 15              1033 RE Amsterdam (Noordelijke IJ-...
# 16              1033 RE Amsterdam (Noordelijke IJ-...
# 17              1033 RE Amsterdam (Noordelijke IJ-...
# 18              1022 KK Amsterdam (Elzenhagen)    ...
# 19              1011 RP Amsterdam (Nieuwmarkt/Last...
# 20              1017 DS Amsterdam (Grachtengordel-...
# 21              1015 CA Amsterdam (Grachtengordel-...
# 22              1017 BR Amsterdam (Grachtengordel-...
# 23              1018 ZC Amsterdam (Oostelijke Eila...
# 24              1075 GW Amsterdam (Willemspark)   ...
# 25              1091 CR Amsterdam (Weesperzijde)  ...
# 26              1013 RJ Amsterdam (Spaarndammer- e...
# 27              1097 GB Amsterdam (Frankendael)   ...
# 28              1054 ZT Amsterdam (Overtoomse Slui...
# 29                1016 RT Amsterdam (Jordaan)
#
#                                             Price    Area    Rooms
# 0                    €2,500 per month               94 m²  3 rooms
# 1                    €1,500 per month               82 m²  4 rooms
# 2                    €1,750 per month               90 m²  3 rooms
# 3                    €2,150 per month               55 m²  3 rooms
# 4                    €2,400 per month               73 m²  3 rooms
# 5                   €10,500 per month              196 m²  4 rooms
# 6                    €2,500 per month               75 m²  3 rooms
# 7                    €2,750 per month              125 m²  3 rooms
# 8                    €1,850 per month               45 m²  2 rooms
# 9                    €1,850 per month               76 m²  3 rooms
# 10                   €2,150 per month               90 m²  5 rooms
# 11                   €2,100 per month               75 m²  2 rooms
# 12                   €2,150 per month               51 m²  3 rooms
# 13                   €1,975 per month               50 m²  2 rooms
# 14                   €1,250 per month               25 m²   1 room
# 15                   €1,740 per month               65 m²  4 rooms
# 16                   €2,450 per month              110 m²  4 rooms
# 17                   €3,400 per month              129 m²  4 rooms
# 18                   €2,650 per month              185 m²  7 rooms
# 19                   €1,600 per month               47 m²  3 rooms
# 20                   €3,400 per month               54 m²  2 rooms
# 21                   €1,995 per month               55 m²  2 rooms
# 22                   €3,850 per month              200 m²  5 rooms
# 23                   €2,500 per month              102 m²  5 rooms
# 24                   €5,500 per month              168 m²  4 rooms
# 25                   €2,400 per month               66 m²  3 rooms
# 26                   €1,950 per month               60 m²  2 rooms
# 27                   €2,300 per month              108 m²  6 rooms
# 28                   €2,075 per month               65 m²  2 rooms
# 29                   €2,450 per month               53 m²  2 rooms
