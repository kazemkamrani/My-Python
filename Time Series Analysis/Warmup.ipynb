# %% [markdown]
# ## Exercise1

# %%
import numpy as np
import matplotlib.pyplot as plt 
df = np.random.standard_normal(1000)
plt.plot(df)

# %%
plt.hist(df,20)
# Out:
# (array([  4.,   8.,  21.,  28.,  52.,  56.,  96., 107., 110.,  99., 117.,
#          85.,  85.,  47.,  43.,  28.,   7.,   5.,   0.,   2.]),
#  array([-2.67568365, -2.38455093, -2.09341821, -1.80228549, -1.51115277,
#         -1.22002005, -0.92888733, -0.63775461, -0.3466219 , -0.05548918,
#          0.23564354,  0.52677626,  0.81790898,  1.1090417 ,  1.40017442,
#          1.69130714,  1.98243986,  2.27357258,  2.56470529,  2.85583801,
#          3.14697073]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Exercise 2

# %%
np.random.seed(19680801)


N = 20
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.plot(x,p(x),"b--")
plt.show()

# %% [markdown]
# ## Exercise 3

# %%
df1= np.cumsum(df)
plt.plot(df1)

# %% [markdown]
# ## Exercise 4

# %%
from scipy import stats

mean = [0, 0]
cov = [[1, 0], [0, 100]]  # diagonal covariance

# %%
x, y = np.random.default_rng().multivariate_normal(mean, cov,1000).T
plt.plot(x, y, 'o')
#plt.axis('equal')
plt.show()

# %% [markdown]
# ## Exercise 5

# %%
Mean = np.mean(df)
Covariance = np.cov(df)
print('Mean =',Mean)
print('Covariance =',Covariance)
# Out:
# Mean = 0.009949379379977178
# Covariance = 1.020920444088212
